# %% [markdown]
# <a href="https://colab.research.google.com/github/soroush-ziaeinejad/NLP_Course/blob/main/Assignment3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pytrec-eval

# %%
# !python main.py
# Out:
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# 8816
# tcmalloc: large alloc 1177542656 bytes == 0x5642420cc000 @  0x7f5fe38a4001 0x7f5fdf22b1af 0x7f5fdf281c23 0x7f5fdf282a87 0x7f5fdf324823 0x56423cab911c 0x56423cab8ef0 0x56423cb2d64d 0x56423caba7aa 0x56423cb2cd30 0x56423cb27a2e 0x56423caba88a 0x56423cb29719 0x56423cb27a2e 0x56423caba88a 0x56423cb2cd30 0x56423cb27a2e 0x56423cb27723 0x56423cbf1812 0x56423cbf1b8d 0x56423cbf1a36 0x56423cbc9183 0x56423cbc8e2c 0x7f5fe268cc87 0x56423cbc8d0a
# ...

# %% [markdown]
# ![Figure_1.png](data:image/png;base64,...)

# %% [markdown]
# ![Capture.PNG](data:image/png;base64,...)

# %%
# !python main.py
# Out:
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# 8816
# mean ndcg ws:1,vs:10: 0.005690232271237199
# mean ndcg ws:1,vs:50: 0.0069269137995657554
# mean ndcg ws:1,vs:100: 0.006648256998869463
# mean ndcg ws:1,vs:300: 0.006251695515209276
# mean ndcg ws:2,vs:10: 0.0067150845546165945
# mean ndcg ws:2,vs:50: 0.007370438576114208
# mean ndcg ws:2,vs:100: 0.006933109781141193
# mean ndcg ws:2,vs:300: 0.006168349498741891
# mean ndcg ws:5,vs:10: 0.006630734504931296
# mean ndcg ws:5,vs:50: 0.005945748077412843
# mean ndcg ws:5,vs:100: 0.00486135301463532
# mean ndcg ws:5,vs:300: 0.004546078408763774
# mean ndcg ws:10,vs:10: 0.005896609001861162
# mean ndcg ws:10,vs:50: 0.0057646628690146366
# mean ndcg ws:10,vs:100: 0.005334872623040313
# mean ndcg ws:10,vs:300: 0.004431502974269867

# %% [markdown]
# **Explanations:**
# results are a little different from the results in the report because in this run number of epochs are set to 25 but in the experiments it was set to 10 to be executed faster.

# %%
# !python main.py
# Out:
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# 8816
